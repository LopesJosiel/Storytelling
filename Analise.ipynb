# %% [markdown]
# # Criação de Repositório GitHub
# - "https://github.com/LopesJosiel/Storytelling.git"
# ## Checklist de atividades da análise exploratória e Storytelling
# - Identificação da fonte de dados "https://www.ibge.gov.br/estatisticas/downloads-estatisticas.html" ok
# - Download dos dados ok
# - extração dos dados para tratamento no pandas ok (extrai as pastas diretamente no windows)
# - Importação de bibliotecas para análise de dados e para geração de gráficos ok
# - Verificação da integridade dos dados (planilhas pequenas não precisei limpar, fiz a selação diretamente)
#     - Identificação se os tipos de dados correspondem
#     - Verficar células vazias e seu tratamento
# - identificação dos tipos de variáveis
# - identificação de valores nulos
#     - contagem de valores nulos para as células
# - tratamento dos valores nulos (exclusão ou substituição)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#corrigindo exportação de pacote matplotlib para geração de gráfico
df1 = pd.read_excel("C:/Users/UNB/Desktop/Mentoria/Dados-Storytelling/2005/celular/tab2011.xls")
display (df1)
# Out:
#    Tabela 2.1.1 - Pessoas de 10 anos ou mais de idade  \
# 0   que tinham telefone móvel celular para uso pes...
# 1          segundo o sexo e os grupos de idade - 2005
# 2                                                 NaN
# 3                            Sexo\ne\ngrupos de idade
# 4                                                 NaN
# 5                                                 NaN
# 6                                           Total (1)
# 7                                        10 a 14 anos
# 8                                        15 a 17 anos
# 9                                       18 ou 19 anos
# 10                                       20 a 24 anos
# 11                                       25 a 29 anos
# 12                                       30 a 39 anos
# 13                                       40 a 49 anos
# 14                                       50 a 59 anos
# 15                                    60 anos ou mais
# ...

# %%
#analisando o total
#selecionando as e a coluna um com informações de faixa etária
age_man = df1.iloc[7:16,0]
#selecionando as linhas e coluna dois com as contagens para cada faixa etária
count_man = df1.iloc[7:16,1]
#plotando o gráfico e escolhendo a cor azul para as barras
plt.bar (age_man,count_man, color= 'gray')
# Análise gráfica: O gráfico sugere uma distribuição normal, o que é esperado para distribuição de uso por faixa etária.
# Out:
# <BarContainer object of 9 artists>

# %%
#analisando homens
#selecionando as e a coluna um com informações de faixa etária
age_man = df1.iloc[17:26,0]
#selecionando as linhas e coluna dois com as contagens para cada faixa etária
count_man = df1.iloc[17:26,1]
#plotando o gráfico e escolhendo a cor azul para as barras
plt.bar (age_man,count_man, color= 'green')
# Out:
# <BarContainer object of 9 artists>

# %%
#analisando mulheres
#selecionando as e a coluna um com informações de faixa etária
age_man = df1.iloc[27:36,0]
#selecionando as linhas e coluna dois com as contagens para cada faixa etária
count_man = df1.iloc[27:36,1]
#plotando o gráfico e escolhendo a cor azul para as barras
plt.bar (age_man,count_man, color= 'pink')
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ### Criação de gráfico de barras agrupadas para análise desses dados por região
# - Utilizando o método iloc do Pandas para captura dos dados por região

# %%
# Dados por região 
norte = df1.iloc[7:16,2]
norte = np.array(norte)
nordeste = df1.iloc[7:16,3]
nordeste = np.array (nordeste)
sudeste = df1.iloc[7:16,4]
sudeste = np.array (sudeste)
sul = df1.iloc[7:16,5]
sul = np.array (sul)
centro_oeste = df1.iloc[7:16,6]
centro_oeste = np.array (centro_oeste)
plt.figure(figsize = (20, 12))
# definindo a largura das barras
barWidth = 0.15

#definindo a posição das barras
l1 = np.arange (len(norte))
l2 = [x + barWidth for x in l1]
l3 = [x + barWidth for x in l2]
l4 = [x + barWidth for x in l3]
l5 = [x + barWidth for x in l4]

# %%
# Criando as barras
plt.bar (l1, norte, color  = '#000000', width = barWidth, label = 'norte')
plt.bar (l2, nordeste, color  = '#0000CD', width = barWidth, label = 'nordeste')
plt.bar (l3, sudeste, color  = '#008000', width = barWidth, label = 'sudeste')
plt.bar (l4, sul, color  = '#00BFFF', width = barWidth, label = 'sul')
plt.bar (l5, centro_oeste, color  = '#20B2AA', width = barWidth, label = 'centro_oeste')

# Adicionando legendas às barras
plt.xlabel ('Faixa Etária')
plt.xticks([l1 + barWidth for l1 in range(len(norte))], ['10 a 14','15 a 17','18 a 19', '20 a 24','25 a 29 ','30 a 39','40 a 49 ','50 a 59', '60 ou +'])
plt.ylabel('Quant. de celulares para uso pessoal')
plt.title('Distribuição de Faixa Etária por Região')
plt.legend ()
plt.plot()
plt.figure(figsize = (60, 25))
plt.savefig ('fig.png')
